# %% [markdown]
# BC District

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import requests

pio.renderers.default = 'browser'

india_districts = json.load(open("geojason final.json",'r'))

map = {}
for feature in india_districts['features']:
    feature['id'] = feature['properties']['GID_3']
    map[feature['properties']['NAME_3']]=feature['id']
    

def fetch_bc_count():
    try:
        url="http://127.0.0.1:5000/api/bcmap?state=Bihar"
        response = requests.get(url)
        return (response.json())
    except Exception as e:
        print(e)
        return None

df = pd.DataFrame(fetch_bc_count(), columns=['StateName','GID_3','District','Count'])
print(df)

statelatlon = {'Maharashtra':[18.66328,74.800293,5.5], 'Chandigarh':[31.441482,76.768066,11], 'HimachalPradesh':[31.884206,77.571167,6.5], 'Bihar':[25.863322,84.869804,6.5], 'Assam':[26.200604,92.937574,6.2], 'Chhattisgarh':[20.995132,81.828232,5.6], 'Telangana':[18.123184,79.208824,6], 'JammuandKashmir':[33.732998,74.864273,6], 'Haryana':[29.065773,76.040497,6.35], 'ArunachalPradesh':[27.995158,93.82737,6.5], 'Manipur':[24.6637,93.9063,7], 'Odisha':[20.2376,84.2700,6.1], 'Rajasthan':[27.0238,74.2179], 'Jharkhand':[23.6913,85.2722], 'AndhraPradesh':[15.9129,79.7400], 'Lakshadweep':[11.114158,72.720374], 'Gujarat':[22.6708,71.5724], 'Nagaland':[26.1584,94.5624], 'Punjab':[31.1471,75.3412], 'UttarPradesh':[27.5706,80.0982], 'NCTofDelhi':[28.7041,77.1025], 'DamanandDiu':[20.397373,72.832802], 'Uttarakhand':[30.0668,79.0193], 'Karnataka':[15.3173,75.7139], 'Goa':[15.2993,74.124], 'Meghalaya':[25.467,91.3662], 'Tripura':[23.5639,91.6761], 'Mizoram':[23.1645,92.9376], 'Sikkim':[27.3516,88.3239], 'Kerala':[10.1632,76.6413], 'AndamanandNicobar':[10.7449,92.5000], 'Puducherry':[11.9416,79.8083], 'TamilNadu':[11.1271,78.6569], 'WestBengal':[24.51782,88.075111], 'MadhyaPradesh':[22.9734,78.6569], 'DadraandNagarHaveli':[20.1809,73.0169]}

temp = df["StateName"][0]

fig = px.choropleth_mapbox(
    df,
    locations="GID_3",
    geojson=india_districts,
    color='Count',
    hover_name="District",
    hover_data=["Count"],
    title="",
    mapbox_style="carto-positron",
    center={"lat": statelatlon[temp][0], "lon": statelatlon[temp][1]},
    # zoom=statelatlon["temp"][2],
    zoom = 5.25,
    opacity=1,
    color_continuous_scale='Blues',
    range_color=(-10,60)
)
fig.show()
fig.write_html("myplot.html")
# Out:
#    StateName         GID_3           District  Count
# 0      Bihar   IND.5.1.1_1             Araria     12
# 1      Bihar   IND.5.2.1_1          Jahanabad      0
# 2      Bihar   IND.5.3.1_1         Aurangabad      0
# 3      Bihar   IND.5.4.1_1              Banka      0
# 4      Bihar   IND.5.5.1_1          Begusarai     27
# 5      Bihar   IND.5.6.1_1          Bhagalpur      5
# 6      Bihar     IND.5.6_1          Bhagalpur      5
# 7      Bihar     IND.5.7_1            Bhojpur      2
# 8      Bihar   IND.5.8.1_1              Buxar      0
# 9      Bihar     IND.5.9_1          Darbhanga     33
# 10     Bihar   IND.5.9.2_1          Darbhanga     33
# 11     Bihar  IND.5.10.1_1               Gaya      0
# 12     Bihar  IND.5.11.1_1          Gopalganj     18
# 13     Bihar  IND.5.12.1_1              Jamui      0
# 14     Bihar  IND.5.13.1_1          Jahanabad      0
# 15     Bihar  IND.5.14.1_1             Bhabua      0
# 16     Bihar  IND.5.15.1_1            Katihar     19
# 17     Bihar  IND.5.16.1_1           Khagaria     14
# 18     Bihar  IND.5.17.1_1         Kishanganj      7
# 19     Bihar  IND.5.18.1_1         Lakhisarai      0
# 20     Bihar  IND.5.19.1_1         Kishanganj      7
# 21     Bihar  IND.5.19.2_1          Madhepura     13
# 22     Bihar    IND.5.20_1          Madhubani     34
# 23     Bihar    IND.5.20_1          Madhubani     34
# 24     Bihar  IND.5.20.3_1          Madhubani     34
# 25     Bihar  IND.5.21.1_1             Munger      0
# 26     Bihar  IND.5.22.1_1        Muzaffarpur     42
# 27     Bihar    IND.5.22_1        Muzaffarpur     42
# 28     Bihar  IND.5.23.1_1        BiharSharif      0
# 29     Bihar  IND.5.23.2_1              Hilsa      0
# 30     Bihar  IND.5.24.1_1             Nawada      1
# 31     Bihar    IND.5.25_1  PashchimChamparan     18
# 32     Bihar  IND.5.26.1_1               Barh      0
# 33     Bihar  IND.5.26.2_1            Danapur      0
# 34     Bihar  IND.5.26.3_1           Masaurhi      0
# 35     Bihar  IND.5.26.4_1          n.a.(652)      0
# 36     Bihar    IND.5.27_1     PurbaChamparan     37
# 37     Bihar    IND.5.27_1     PurbaChamparan     37
# 38     Bihar  IND.5.28.1_1             Purnia     18
# 39     Bihar    IND.5.29_1             Rohtas      1
# 40     Bihar  IND.5.30.1_1            Saharsa     12
# 41     Bihar    IND.5.31_1         Samastipur     37
# 42     Bihar    IND.5.31_1         Samastipur     37
# 43     Bihar  IND.5.31.3_1         Samastipur     37
# 44     Bihar    IND.5.32_1              Saran     47
# 45     Bihar  IND.5.33.1_1         Sheikhpura      0
# 46     Bihar  IND.5.34.1_1            Sheohar      2
# 47     Bihar    IND.5.35_1          Sitamarhi     23
# 48     Bihar  IND.5.35.2_1          Sitamarhi     23
# 49     Bihar  IND.5.36.1_1              Siwan     34
# 50     Bihar    IND.5.37_1             Supaul     20
# 51     Bihar  IND.5.37.2_1             Supaul     20
# 52     Bihar    IND.5.38_1           Vaishali     29

# %% [markdown]
# BC State

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import requests
pio.renderers.default = 'browser'

india_districts = json.load(open("states_india.geojson",'r'))

map = {}
for feature in india_districts['features']:
    feature['id'] = feature['properties']['state_code']
    map[feature['properties']['st_nm']]=feature['id']
    
def fetch_bc_count():
    try:
        url="http://127.0.0.1:5000/api/bcagents"
        response = requests.get(url)
        return (response.json())
    except Exception as e:
        print(e)
        return None

df = pd.DataFrame(fetch_bc_count(), columns=['GID_1','State','Count'])
print(df)
    
fig = px.choropleth_mapbox(
    df,
    locations="GID_1",
    geojson=india_districts,
    color="Count",
    hover_name="State",
    hover_data=["Count"],
    title="",
    mapbox_style="carto-positron",
    center={"lat": 23.2937, "lon": 62.9629},
    zoom=3.45,
    opacity=1,
    color_continuous_scale='Blues',
    range_color=(-10,60)
)
fig.show()
fig.write_html("myplot.html")
# Out:
# HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/bcagents (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000011CAACB13D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Empty DataFrame
# Columns: [GID_1, State, Count]
# Index: []

# %% [markdown]
# Crops State

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import requests
pio.renderers.default = 'browser'

india_districts = json.load(open("states_india.geojson",'r'))

map = {}
for feature in india_districts['features']:
    feature['id'] = feature['properties']['state_code']
    map[feature['properties']['st_nm']]=feature['id']
    
def fetch_bc_count():
    try:
        url="http://127.0.0.1:5002/api/cropsmap"
        response = requests.get(url)
        return (response.json())
    except Exception as e:
        print(e)
        return None

df = pd.DataFrame(fetch_bc_count(), columns=['GID_1','State','Production'])
print(df)
    
fig = px.choropleth_mapbox(
    df,
    locations="GID_1",
    geojson=india_districts,
    color="Production",
    hover_name="State",
    hover_data=["Production"],
    title="",
    mapbox_style="carto-positron",
    center={"lat": 23.2937, "lon": 62.9629},
    zoom=3.45,
    opacity=1,
    color_continuous_scale='Blues',
    range_color=(-10,100000000)
)
fig.show()
# Out:
#     GID_1                     State    Production
# 0       0                 Telangana  0.000000e+00
# 1      35  Andaman & Nicobar Island  0.000000e+00
# 2      28            Andhra Pradesh  2.132282e+09
# 3      12        Arunanchal Pradesh  4.813420e+05
# 4      18                     Assam  1.532749e+07
# 5      10                     Bihar  3.203288e+07
# 6      22              Chhattisgarh  9.516579e+06
# 7      25               Daman & Diu  0.000000e+00
# 8      30                       Goa  3.839850e+05
# 9      24                   Gujarat  0.000000e+00
# 10      6                   Haryana  0.000000e+00
# 11      2          Himachal Pradesh  0.000000e+00
# 12      1           Jammu & Kashmir  0.000000e+00
# 13     20                 Jharkhand  0.000000e+00
# 14     29                 Karnataka  6.861459e+07
# 15     32                    Kerala  5.951363e+09
# 16     31               Lakshadweep  0.000000e+00
# 17     23            Madhya Pradesh  0.000000e+00
# 18     27               Maharashtra  1.082016e+08
# 19     14                   Manipur  0.000000e+00
# 20      4                Chandigarh  0.000000e+00
# 21     34                Puducherry  2.559034e+07
# 22      3                    Punjab  3.525440e+07
# 23      8                 Rajasthan  0.000000e+00
# 24     11                    Sikkim  1.057180e+05
# 25     33                Tamil Nadu  0.000000e+00
# 26     16                   Tripura  8.223660e+05
# 27      9             Uttar Pradesh  1.994189e+08
# 28      5               Uttarakhand  1.187386e+07
# 29     19               West Bengal  4.358440e+07
# 30     21                    Odisha  1.111221e+07
# 31     26    Dadara & Nagar Havelli  2.794100e+04
# 32     17                 Meghalaya  8.526300e+05
# 33     15                   Mizoram  0.000000e+00
# 34     13                  Nagaland  1.147430e+06
# 35      7              NCT of Delhi  0.000000e+00

# %% [markdown]
# Crops District

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import requests

pio.renderers.default = 'browser'

india_districts = json.load(open("geojason final.json",'r'))

map = {}
for feature in india_districts['features']:
    feature['id'] = feature['properties']['GID_3']
    map[feature['properties']['NAME_3']]=feature['id']
    

def fetch_bc_count():
    try:
        url="http://127.0.0.1:5002/api/cropsmap"
        response = requests.get(url)
        return (response.json())
    except Exception as e:
        print(e)
        return None

df = pd.DataFrame(fetch_bc_count(), columns=['StateName','GID_3','District','Production'])
print(df)

statelatlon = {'Maharashtra':[18.66328,74.800293,5.5], 'Chandigarh':[31.441482,76.768066,11], 'HimachalPradesh':[31.884206,77.571167,6.5], 'Bihar':[25.863322,84.869804,6.5], 'Assam':[26.200604,92.937574,6.2], 'Chhattisgarh':[20.995132,81.828232,5.6], 'Telangana':[18.123184,79.208824,6], 'JammuandKashmir':[33.732998,74.864273,6], 'Haryana':[29.065773,76.040497,6.35], 'ArunachalPradesh':[27.995158,93.82737,6.5], 'Manipur':[24.6637,93.9063,7], 'Odisha':[20.2376,84.2700,6.1], 'Rajasthan':[27.0238,74.2179], 'Jharkhand':[23.6913,85.2722], 'AndhraPradesh':[15.9129,79.7400], 'Lakshadweep':[11.114158,72.720374], 'Gujarat':[22.6708,71.5724], 'Nagaland':[26.1584,94.5624], 'Punjab':[31.1471,75.3412], 'UttarPradesh':[27.5706,80.0982], 'NCTofDelhi':[28.7041,77.1025], 'DamanandDiu':[20.397373,72.832802], 'Uttarakhand':[30.0668,79.0193], 'Karnataka':[15.3173,75.7139], 'Goa':[15.2993,74.124], 'Meghalaya':[25.467,91.3662], 'Tripura':[23.5639,91.6761], 'Mizoram':[23.1645,92.9376], 'Sikkim':[27.3516,88.3239], 'Kerala':[10.1632,76.6413], 'AndamanandNicobar':[10.7449,92.5000], 'Puducherry':[11.9416,79.8083], 'TamilNadu':[11.1271,78.6569], 'WestBengal':[24.51782,88.075111], 'MadhyaPradesh':[22.9734,78.6569], 'DadraandNagarHaveli':[20.1809,73.0169]}

temp = df["StateName"][0]

fig = px.choropleth_mapbox(
    df,
    locations="GID_3",
    geojson=india_districts,
    color='Production',
    hover_name="District",
    hover_data=['Production'],
    title="",
    mapbox_style="carto-positron",
    center={"lat": statelatlon[temp][0], "lon": statelatlon[temp][1]},
    # zoom=statelatlon["temp"][2],
    zoom = 5.25,
    opacity=1,
    color_continuous_scale='Blues',
    range_color=(-10, 40)
)
fig.show()
# fig.write_html("myplot.html")
# Out:
#               StateName          GID_3        District  Production
# 0     AndamanandNicobar    IND.1.1.1_1      n.a.(2304)         0.0
# 1     AndamanandNicobar    IND.1.2.1_1      n.a.(2178)         0.0
# 2     AndamanandNicobar    IND.1.3.1_1      n.a.(2178)         0.0
# 3         AndhraPradesh    IND.2.1.1_1       Anantapur   6776061.0
# 4         AndhraPradesh    IND.2.1.2_1     Dharmavaram         0.0
# ...                 ...            ...             ...         ...
# 2342         WestBengal  IND.36.19.1_1  DiamondHarbour         0.0
# 2343         WestBengal  IND.36.19.2_1      n.a.(1187)         0.0
# 2344         WestBengal  IND.36.19.3_1      n.a.(1229)         0.0
# 2345         WestBengal  IND.36.20.1_1        Islampur         0.0
# 2346         WestBengal  IND.36.20.2_1         Raiganj         0.0
#
# [2347 rows x 4 columns]
